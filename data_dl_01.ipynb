# %% [markdown]
# <a href="https://colab.research.google.com/github/kimkim1029/Esther-Hahyeon-Kim/blob/main/data_dl_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Deeplearning - Numpy 
import numpy as np
print(np.__version__)

my_arr = np.array([[1,2,3], [4,5,6]])
print(my_arr)

type(my_arr)

my_arr[0][2]

np.sum(my_arr)
# Out:
# 1.19.4
# [[1 2 3]
#  [4 5 6]]
# 21

# %%
# Deeplearning - Matplotlib
import matplotlib.pyplot as plt 

plt.plot([1,2,3,4,5], [1,4,9,16,25])
plt.show()

plt.scatter([1,2,3,4,5], [1,4,9,16,25])
plt.show()

x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x,y)
plt.show()

# %%
# Deeplearnong - Prediction

from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
